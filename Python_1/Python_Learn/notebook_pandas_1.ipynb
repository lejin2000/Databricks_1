# %%
import pandas as pd
import numpy as np

df_sales = pd.read_csv('/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/sales-csv/000.csv' , sep='|')
#display(df_sales)
#print(len(df_sales))
print (range(len(df_sales)))

# %%
for i in range(10): #range(len(df_sales))
    print(df_sales.iloc[i]['order_id'])
