-- %%
select * from workspace.default.dividend where transaction_details like "%tgl%"
select * from workspace.default.cgs_portfolio_yahoo order by name where symbol like "%mbb%"


select symbol, 
concat('%',replace(portfolio.symbol,".KL",''),'%'),
concat('%',substring(replace(portfolio.symbol,".KL",''),0,4),'%')
from workspace.default.cgs_portfolio_yahoo  as portfolio
--select count(1), year(date_audit) from workspace.default.dividend group by year(date_audit) order by year(date_audit)

--select distinct(source_file) from from workspace.default.dividend
--select * from workspace.default.hlebroking_portfolio_yahoo 

with dividen_clean_output AS (
  select date,
  regexp_replace(d.transaction_details, '\\ CIMB$|BURSA MALAYSIA DEPOS|BOARDROOM SHARE REGI|TMF TRUSTEES MALAYSI', '') as transaction_details_clean,transaction_details
  ,currency,money_in,source_file,date_modified,date_audit
  from workspace.default.dividend d
) ,
portfolio_all_like_match AS (
  SELECT name, symbol
  FROM workspace.default.cgs_portfolio_yahoo
  UNION ALL
  SELECT name, stock_name AS symbol
  FROM workspace.default.hlebroking_portfolio_yahoo
)
select * 
from dividen_clean_output d
left join portfolio_all_like_match e on d.transaction_details_clean like concat('%',replace(e.symbol,".KL",''),'%')
where  d.transaction_details_clean like '%lpi%'
limit 10
